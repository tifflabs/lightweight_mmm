# %%
# %pip install --upgrade pip

# %pip install lightweight_mmm
# %pip install immutabledict
# %pip install numpyro
# %pip install pandas
# %pip install scikit-learn
# %pip install statsmodels
# %pip install tensorflow-macos
# Out:
# Requirement already satisfied: pip in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (23.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Collecting lightweight_mmm
#   Using cached lightweight_mmm-0.1.7-py3-none-any.whl (103 kB)
# Collecting arviz==0.11.2
#   Using cached arviz-0.11.2-py3-none-any.whl (1.6 MB)
# Collecting lightweight_mmm
#   Using cached lightweight_mmm-0.1.6-py3-none-any.whl (71 kB)
# Requirement already satisfied: jaxlib>=0.3.14 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (0.4.6)
# Collecting matplotlib==3.3.4
#   Using cached matplotlib-3.3.4.tar.gz (37.9 MB)
#   Preparing metadata (setup.py) ... done
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting seaborn==0.11.1
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# Requirement already satisfied: immutabledict>=2.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (2.2.3)
# Requirement already satisfied: pandas>=1.1.5 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (1.5.3)
# Requirement already satisfied: scipy in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (1.10.1)
# Collecting lightweight_mmm
#   Using cached lightweight_mmm-0.1.5-py3-none-any.whl (63 kB)
#   Using cached lightweight_mmm-0.1.4-py3-none-any.whl (60 kB)
# Collecting frozendict
#   Using cached frozendict-2.3.6.tar.gz (35 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lightweight_mmm
#   Using cached lightweight_mmm-0.1.3-py3-none-any.whl (53 kB)
# Requirement already satisfied: numpyro>=0.8.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (0.11.0)
# Requirement already satisfied: jax>=0.3.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from lightweight_mmm) (0.4.6)
#   Using cached lightweight_mmm-0.1.2-py3-none-any.whl (48 kB)
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting arviz
#   Using cached arviz-0.15.1-py3-none-any.whl (1.6 MB)
# Collecting lightweight_mmm
#   Using cached lightweight_mmm-0.1.1-py3-none-any.whl (41 kB)
#   Using cached lightweight_mmm-0.1.0-py3-none-any.whl (40 kB)
# ERROR: Cannot install lightweight-mmm==0.1.0, lightweight-mmm==0.1.1, lightweight-mmm==0.1.2, lightweight-mmm==0.1.3, lightweight-mmm==0.1.4, lightweight-mmm==0.1.5, lightweight-mmm==0.1.6 and lightweight-mmm==0.1.7 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     lightweight-mmm 0.1.7 depends on tensorflow>=2.7.2
#     lightweight-mmm 0.1.6 depends on tensorflow>=2.7.2
#     lightweight-mmm 0.1.5 depends on tensorflow>=2.7.2
#     lightweight-mmm 0.1.4 depends on tensorflow==2.7.2
#     lightweight-mmm 0.1.3 depends on tensorflow==2.7.2
#     lightweight-mmm 0.1.2 depends on tensorflow==2.5.3
#     lightweight-mmm 0.1.1 depends on tensorflow==2.5.3
#     lightweight-mmm 0.1.0 depends on tensorflow==2.4.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: immutabledict in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpyro in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: tqdm in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from numpyro) (4.64.1)
# Requirement already satisfied: jaxlib>=0.4 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from numpyro) (0.4.6)
# Requirement already satisfied: jax>=0.4 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from numpyro) (0.4.6)
# Requirement already satisfied: multipledispatch in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from numpyro) (0.6.0)
# Requirement already satisfied: numpy in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from numpyro) (1.24.2)
# Requirement already satisfied: opt-einsum in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from jax>=0.4->numpyro) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from jax>=0.4->numpyro) (1.10.1)
# Requirement already satisfied: six in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from multipledispatch->numpyro) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pandas) (2023.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from scikit-learn) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: scipy>=1.3 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: packaging>=21.3 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from statsmodels) (23.0)
# Requirement already satisfied: numpy>=1.17 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from statsmodels) (1.24.2)
# Requirement already satisfied: patsy>=0.5.2 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2023.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow-macos in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (2.11.0)
# Requirement already satisfied: setuptools in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (66.1.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (2.11.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.51.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (23.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: packaging in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (23.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.15.0)
# Requirement already satisfied: numpy>=1.20 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.24.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (4.5.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorflow-macos) (16.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.16.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-macos) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/tiffanyblakeney/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Let'from lightweight_mmm import lightweight_mmm
from lightweight_mmm import optimize_media
from lightweight_mmm import plot
from lightweight_mmm import preprocessing
from lightweight_mmm import utils
media_data, extra_features, target, costs = utils.simulate_dummy_data(
    data_size=160,
    n_media_channels=3,
    n_extra_features=2,
    geos=5) # Or geos=1 for national model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Let'from lightweight_mmm import lightweight_mmm
# ----> 2 from lightweight_mmm import optimize_media
#       3 from lightweight_mmm import plot
#       4 from lightweight_mmm import preprocessing
#
# ModuleNotFoundError: No module named 'lightweight_mmm'
